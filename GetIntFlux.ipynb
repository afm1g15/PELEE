# %%
import os
import uproot
import numpy as np
import time
import matplotlib.pyplot as plt
import sys
from scipy.stats import chisquare

# %%
#####NUE

# %%
fhcHisto = uproot.open( "flux_newg4.root")['nue_cv_fhc']   
rhcHisto = uproot.open( "flux_newg4.root")['nue_cv_rhc']

# %%
binsFHC    = fhcHisto.bins
valueFHC   = fhcHisto.values
binsRHC    = rhcHisto.bins
valueRHC   = rhcHisto.values

# %%
valueFHC[:12] # if each bin is 5 MeV, first 12 bins are 60 MeV
valueRHC[:12] # if each bin is 5 MeV, first 12 bins are 60 MeV
# Out:
# array([3.26335307e+08, 2.07669379e+09, 5.03512390e+09, 8.59138233e+09,
#        1.21330319e+10, 1.50736577e+10, 1.67445342e+10, 1.66570245e+10,
#        1.41644344e+10, 8.60967902e+09, 1.14107125e+09, 2.54139077e+07])

# %%
print("FHC: ", sum(valueFHC[11:] ))    #*1E-4 for int flux
print("RHC: ", sum(valueRHC[11:] ))
# Out:
# FHC:  7375965345.870582
# RHC:  5440192302.801636

# %%
######NUMU

# %%
fhcHisto_numu = uproot.open( "flux_newg4.root")['numu_cv_fhc']
rhcHisto_numu = uproot.open( "flux_newg4.root")['numu_cv_rhc']

# %%
binsFHC_numu   = fhcHisto_numu.bins
valueFHC_numu  = fhcHisto_numu.values
binsRHC_numu   = rhcHisto_numu.bins
valueRHC_numu  = rhcHisto_numu.values

# %%
print("FHC: ", sum(valueFHC_numu[11:] ))
print("RHC: ", sum(valueRHC_numu[11:] ))
# Out:
# FHC:  269486188087.87604
# RHC:  178334683580.59155
